# %%
import healpy as hp
import matplotlib.pyplot as plt
import numpy as np

def make_plot(skymap=None, header=None):
    header = dict(header)
    for key in header:
        print(key, ' : ', header[key])
    #print(header)

    if skymap is not None:
        cmap = plt.cm.YlOrBr
        cmap.set_under('w')
        hp.mollview(skymap, title="", cbar=True, notext=True, rot=180, hold=False, cmap=cmap)
        hp.graticule()
        # add some labels
        plt.text(2.0,0., r"$0^\circ$", ha="left", va="center")
        plt.text(1.9,0.45, r"$30^\circ$", ha="left", va="center")
        plt.text(1.4,0.8, r"$60^\circ$", ha="left", va="center")
        plt.text(1.9,-0.45, r"$-30^\circ$", ha="left", va="center")
        plt.text(1.4,-0.8, r"$-60^\circ$", ha="left", va="center")
        plt.text(2.0, -0.15, r"$0\,\mathrm{h}$", ha="center", va="center")
        plt.text(1.333, -0.15, r"$4\,\mathrm{h}$", ha="center", va="center")
        plt.text(.666, -0.15, r"$8\,\mathrm{h}$", ha="center", va="center")
        plt.text(0.0, -0.15, r"$12\,\mathrm{h}$", ha="center", va="center")
        plt.text(-.666, -0.15, r"$16\,\mathrm{h}$", ha="center", va="center")
        plt.text(-1.333, -0.15, r"$20\,\mathrm{h}$", ha="center", va="center")
        plt.text(-2.0, -0.15, r"$0\,\mathrm{h}$", ha="center", va="center")
        plt.draw()
    
        print(skymap)
        print(skymap.min())
        print(np.amin(skymap))
        min_bin = np.where(skymap == np.amin(skymap))[0][0]
        print(min_bin)
    
        theta, phi = hp.pix2ang(1024, min_bin)
        print (-np.degrees(theta-np.pi/2.), np.degrees(phi))

        #memfile = io.BytesIO()
        plt.savefig('tmp.png', format = 'png', dpi = 150)
        #memfile.seek(0)
    print(len(header),len(skymap),type(skymap[0]))

# %%
skymap, header = hp.read_map('../fits/Run138198_44334860_nside512.fits.gz',h=True, verbose=False)
make_plot(skymap,header)
# Out:
# /var/folders/v2/pgv7w8dx6qd2m9129rm0dfyw0000gn/T/ipykernel_53772/1904056454.py:1: HealpyDeprecationWarning: "verbose" was deprecated in version 1.15.0 and will be removed in a future version.
#   skymap, header = hp.read_map('../fits/Run138198_44334860_nside512.fits.gz',h=True, verbose=False)
# XTENSION  :  BINTABLE
# BITPIX  :  8
# NAXIS  :  2
# NAXIS1  :  4096
# NAXIS2  :  3072
# PCOUNT  :  0
# GCOUNT  :  1
# TFIELDS  :  1
# TTYPE1  :  2LLH
# TFORM1  :  1024E
# PIXTYPE  :  HEALPIX
# ORDERING  :  RING
# COORDSYS  :  C
# EXTNAME  :  xtension
# NSIDE  :  512
# FIRSTPIX  :  0
# LASTPIX  :  3145727
# INDXSCHM  :  IMPLICIT
# OBJECT  :  FULLSKY
# RUNID  :  138198
# EVENTID  :  44334860
# SENDER  :  IceCube Collaboration
# START  :  2023-07-27 16:05:39.630288
# EVENTMJD  :  60152.67059757279
# I3TYPE  :  gfu-bronze
# RA  :  33.66
# DEC  :  7.63
# RA_ERR_PLUS  :  1.14
# RA_ERR_MINUS  :  0.7
# DEC_ERR_PLUS  :  0.6
# DEC_ERR_MINUS  :  0.68
# ENERGY  :  113
# FAR  :  3.38
# SIGNAL  :  0.294
# CASCADE_SCR  :  4.88e-06
# SKIMMING_SCR  :  9.16e-10
# START_SCR  :  1.0
# STOP_SCR  :  1.08e-07
# THRGOING_SCR  :  5.29e-05
# COMMENTS  :  50%(90%) uncertainty location => Change in 2LLH of 22.2(64.2)
# NOTE  :  Please ignore pixels with infinite or NaN values. They are rare cases of the minimizer failing to converge
# GCN_URL  :  https://gcn.nasa.gov/circulars/34276
# CR_VETO  :  False
# [17405.94  17430.543 17394.193 ... 17360.59  17366.008 17382.39 ]
# 0.0
# 0.0
# 1363135
# 51.546240405220125 25.65980629539952
# 43 3145728 <class 'numpy.float32'>
